# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
#
# Object-Oriented Programming (OOP) is a programming approach that uses classes and objects to organize code and represent real-world entities.
#
# Example:
# class Car:
#     pass
#
# 2. What is a class in OOP?
#
# A class is a blueprint used to create objects. It defines variables and methods.
#
# Example:
# class Person:
#     name = "John"
#
# 3. What is an object in OOP?
#
# An object is an instance of a class that can use the class properties and methods.
#
# Example:
# p1 = Person()
# print(p1.name)
#
# 4. Difference between abstraction and encapsulation
# Abstraction	                                                            Encapsulation
# Hides complex implementation	                                 Hides data using access control
#
# Example:                                                                   Example:  class BankAccount:
#                                                                                       def __init__(self):
#                                                                      self.__balance = 1000   # private variable
#
#                                                                                def deposit(self, amount):
#                                                                                   self.__balance += amount
#
#                                                                                  def get_balance(self):
#                                                                               return self.__balance
#
#                                                                                  acc = BankAccount()
#                                                                                acc.deposit(500)
#                                                                            print(acc.get_balance())
#
# from abc import ABC, abstractmethod
#
# class Shape(ABC):
#     @abstractmethod
#     def area(self):
#         pass
#
# class Circle(Shape):
#     def area(self):
#         return 3.14 * 5 * 5
#
# c = Circle()
# print(c.area())
#
#
# 5. What are dunder methods in Python?
#
# Dunder methods are special methods with double underscores used to define object behavior.
#
# Example:
#
# class Demo:
#     def __init__(self):
#         print("Object created")
#
# 6. Explain the concept of inheritance in OOP.
#
# Inheritance allows a child class to use properties and methods of a parent class.
#
# Example:
#
# class Animal:
#     def sound(self):
#         print("Animal sound")
#
# class Dog(Animal):
#     pass
#
# 7. What is polymorphism in OOP?
#
# Polymorphism means same method name but different behavior in different classes.
#
# Example:
#
# class Cat:
#     def sound(self):
#         print("Meow")
#
# class Dog:
#     def sound(self):
#         print("Bark")
#
# 8. How is encapsulation achieved in Python?
#
# Encapsulation is achieved using private variables with __.
#
# Example:
#
# class Bank:
#     def __init__(self):
#         self.__balance = 1000
#
# 9. What is a constructor in Python?
#
# A constructor is a special method __init__() used to initialize object attributes.
#
# Example:
#
# class Student:
#     def __init__(self, name):
#         self.name = name
#
#
#
# 10. What are class and static methods?
#
# Class method works with class variables.
#
# Static method does not use class or instance data.
#
# Example:
#
# class Math:
#
#     @classmethod
#     def add(cls,a,b):
#         return a+b
#
#     @staticmethod
#     def sub(a,b):
#         return a-b
#
#
# 11. What is method overloading in Python?
#
# Method overloading means same method name with different parameters.
#
# Example:
#
# def add(a,b,c=0):
#     return a+b+c
#
#
# 12. What is method overriding?
#
# Method overriding happens when a child class changes a method of the parent class.
#
# Example:
#
# class Animal:
#     def sound(self):
#         print("Animal sound")
#
# class Dog(Animal):
#     def sound(self):
#         print("Bark")
#
#
# 13. What is a property decorator?
#
# @property allows a method to be used like an attribute.
#
# Example:
#
# class Demo:
#     @property
#     def value(self):
#         return 10
#
#
# 14. Why is polymorphism important?
#
# Polymorphism allows same interface for different objects, making code flexible and reusable.
#
# Example:
#
# for animal in [Dog(), Cat()]:
#     animal.sound()
#
#
# 15. What is an abstract class?
#
# An abstract class cannot be instantiated and contains abstract methods.
#
# Example:
#
# from abc import ABC, abstractmethod
#
# class Shape(ABC):
#     @abstractmethod
#     def area(self):
#         pass
#
#
# 16. What are the advantages of OOP.
#
# Advantages of OOP
# - Code reuse
# - Better structure
# - Security through encapsulation
# - Easy maintenance
#
# Example: Inheritance in classes.
#
#
# 17. What is the difference between a class variable and an instance variable.
#
# - Difference between class variable and instance variable
# Class Variable	                           Instance Variable
# Shared by all objects	Unique for each object
#
# Example:
#
# class Test:
#     x = 10
#     def __init__(self,y):
#        self.y = y
#
# 18. What is multiple inheritance?
#
# Multiple inheritance means a class inherits from more than one parent class.
#
# Example:
#
# class A:
#     pass
#
# class B:
#     pass
#
# class C(A,B):
#     pass
#
# 19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.
#
# => Purpose of __str__ and __repr__
#
# __str__ returns a readable string representation of an object.
#
# Example:
#
# class Test:
#     def __str__(self):
#         return "Hello"
#
#
# 20. What is the significance of the ‘super()’ function in Python.
#
# Significance of super() function
#
# super() is used to call methods from the parent class.
#
# Example:
#
# class A:
#     def show(self):
#         print("Parent")
#
# class B(A):
#     def show(self):
#         super().show()
#
# 21. What is the significance of the __del__ method in Python.
#
# Significance of __del__
#
# __del__ is a destructor method called when an object is destroyed.
#
# Example:
#
# class Demo:
#     def __del__(self):
#         print("Object deleted")
#
# 22. What is the difference between @staticmethod and @classmethod in Python.
#
#
# Difference between @staticmethod and @classmethod
# Static Method	Class Method
# No access to class	Access to class
#
# Example:
#
# class Demo:
#
#     @staticmethod
#     def hello():
#         print("Hi")
#
#     @classmethod
#     def world(cls):
#         print("Hello")
#
# 23. How does polymorphism works with inheritance.
#
# Different child classes override the same method differently.
#
# Example:
#
# class Bird:
#     def fly(self):
#         print("Flying")
#
# class Penguin(Bird):
#     def fly(self):
#         print("Cannot fly")
#
# 24. What is method chaining?
#
# Method chaining allows multiple methods to be called in one line.
#
# Example:
#
# class Test:
#     def add(self):
#         print("Add")
#         return self
#
# 25. Purpose of __call__ method
#
# __call__ allows an object to be used like a function.
#
# Example:
#
# class Demo:
#     def __call__(self):
#         print("Object called")
#
# d = Demo()
# d()`

# %%
#practical questions

1) Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog
that overrides the speak() method to print "Bark!".

class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

d = Dog()
d.speak()

# %%
2) Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle
from it and implement the area() method in both.

from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, r):
        self.r = r

    def area(self):
        return math.pi * self.r * self.r

class Rectangle(Shape):
    def __init__(self,l,w):
        self.l = l
        self.w = w

    def area(self):
        return self.l * self.w

c = Circle(5)
r = Rectangle(4,6)

print("Circle Area:", c.area())
print("Rectangle Area:", r.area())

# %%
3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car
and further derive a class ElectricCar that adds a battery attribute.

class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    pass

class ElectricCar(Car):
    def __init__(self, type, battery):
        super().__init__(type)
        self.battery = battery

e = ElectricCar("Car", "Lithium Battery")
print(e.type, e.battery)

# %%
4) Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes
Sparrow and Penguin that override the fly() method.

class Bird:
    def fly(self):
        print("Bird can fly")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")

b1 = Sparrow()
b2 = Penguin()

b1.fly()
b2.fly()

# %%
5) Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes
balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self):
        self.__balance = 0

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        self.__balance -= amount

    def check_balance(self):
        print("Balance:", self.__balance)

acc = BankAccount()
acc.deposit(500)
acc.withdraw(200)
acc.check_balance()

# %%
6) Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar
and Piano that implement their own version of play().

class Instrument:
    def play(self):
        print("Playing instrument")

class Guitar(Instrument):
    def play(self):
        print("Playing Guitar")

class Piano(Instrument):
    def play(self):
        print("Playing Piano")

g = Guitar()
p = Piano()

g.play()
p.play()

# %%
7) Create a class MathOperations with a class method add_numbers() to add two numbers and a static
method subtract_numbers() to subtract two numbers

class MathOperations:

    @classmethod
    def add_numbers(cls,a,b):
        return a + b

    @staticmethod
    def subtract_numbers(a,b):
        return a - b

print(MathOperations.add_numbers(5,3))
print(MathOperations.subtract_numbers(10,4))

# %%
8) Implement a class Person with a class method to count the total number of persons created.

class Person:
    count = 0

    def __init__(self):
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

p1 = Person()
p2 = Person()

print("Total Persons:", Person.total_persons())

# %%
9) Write a class Fraction with attributes numerator and denominator. Override the str method to display the
fraction as "numerator/denominator".

class Fraction:
    def __init__(self,n,d):
        self.n = n
        self.d = d

    def __str__(self):
        return f"{self.n}/{self.d}"

f = Fraction(3,4)
print(f)

# %%
10) Demonstrate operator overloading by creating a class Vector and overriding the add method to add two
vectors.

class Vector:
    def __init__(self,x,y):
        self.x = x
        self.y = y

    def __add__(self,other):
        return Vector(self.x + other.x , self.y + other.y)

    def display(self):
        print(self.x,self.y)

v1 = Vector(2,3)
v2 = Vector(4,5)

v3 = v1 + v2
v3.display()

# %%
11) Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
{name} and I am {age} years old."

class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("Rahul",22)
p.greet()
# Out:
#   File "/tmp/ipykernel_516/3220549807.py", line 1
#     11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is
#                                                                                              ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
12) Implement a class Student with attributes name and grades. Create a method average_grade() to compute
the average of the grades

class Student:
    def __init__(self,name,grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades)/len(self.grades)

s = Student("Amit",[80,90,85])
print("Average:", s.average_grade())

# %%
13) Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the
area.

class Rectangle:

    def set_dimensions(self,l,w):
        self.l = l
        self.w = w

    def area(self):
        return self.l * self.w

r = Rectangle()
r.set_dimensions(4,5)
print("Area:", r.area())

# %%
14) Create a class Employee with a method calculate_salary() that computes the salary based on hours worked
and hourly rate. Create a derived class Manager that adds a bonus to the salary.

class Employee:
    def calculate_salary(self,hours,rate):
        return hours * rate

class Manager(Employee):
    def calculate_salary(self,hours,rate):
        salary = super().calculate_salary(hours,rate)
        return salary + 500

m = Manager()
print("Salary:", m.calculate_salary(40,20))

# %%
15)  Create a class Product with attributes name, price, and quantity. Implement a method total_price() that
calculates the total price of the product.

class Product:
    def __init__(self,name,price,qty):
        self.name = name
        self.price = price
        self.qty = qty

    def total_price(self):
        return self.price * self.qty

p = Product("Pen",10,5)
print("Total Price:", p.total_price())

# %%
16) Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that
implement the sound() method.

from abc import ABC, abstractmethod

class Animal(ABC):

    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Moo")

class Sheep(Animal):
    def sound(self):
        print("Baa")

c = Cow()
s = Sheep()

c.sound()
s.sound()

# %%
17) Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that
returns a formatted string with the book's details.

class Book:

    def __init__(self,title,author,year):
        self.title = title
        self.author = author
        self.year = year

    def get_book_info(self):
        return f"{self.title} by {self.author}, {self.year}"

b = Book("Python Basics","John",2022)
print(b.get_book_info())

# %%
18) Create a class House with attributes address and price. Create a derived class Mansion that adds an
attribute number_of_rooms.

class House:
    def __init__(self,address,price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self,address,price,rooms):
        super().__init__(address,price)
        self.rooms = rooms

m = Mansion("Park Street",500000,10)

print("Address:",m.address)
print("Price:",m.price)
print("Rooms:",m.rooms)
